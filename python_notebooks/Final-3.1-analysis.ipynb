# %% [markdown]
# # Main Visualization
#
# ## Exploration

# %%
# Load in dataset
import pandas as pd
import altair as alt
df = pd.read_csv("https://raw.githubusercontent.com/wadefagen/datasets/master/gpa/uiuc-gpa-dataset.csv")

# %%
df['Students'] = df['A+'] + df['A'] + df['A-'] + df['B+'] + df['B'] + df['B-'] + df['C+'] + df['C'] + df['C-'] + df['D+'] + df['D'] + df['D-'] + df['F']

# %%
# Then, use the students column to find Average GPA 
# (scale: https://registrar.illinois.edu/courses-grades/explanation-of-grades/)
df['Average GPA'] = (df['A+'] * 4.0 + df['A'] * 4.0 + df['A-'] * 3.67 \
                     + df['B+'] * 3.33 + df['B'] * 3.0 + df['B-'] * 2.67 \
                     + df['C+'] * 2.33 + df['C'] * 2.0 + df['C-'] * 1.67 \
                     + df['D+'] * 1.33 + df['D'] * 1.0 + df['D-'] * 0.67) / df['Students']

# %%
df = df[df['Sched Type'] == 'LEC']

# %%
# Group the data by course title and count the number of unique primary instructors
course_counts = df.groupby('Course Title')['Primary Instructor'].nunique()

# Filter the dataframe to include only courses with multiple instructors
df = df[df['Course Title'].isin(course_counts[course_counts > 1].index)]
df
# Out:
#        Year    Term YearTerm Subject  Number                    Course Title
# 5      2023  Spring  2023-sp     ABE     141      ABE Principles: Biological  \
# 106    2023  Spring  2023-sp     ACE     210         Environmental Economics
# 113    2023  Spring  2023-sp     ACE     262  App Stat Mthds & Data AnlytcsI
# 115    2023  Spring  2023-sp     ACE     270              Consumer Economics
# 116    2023  Spring  2023-sp     ACE     300  Interm. Applied Microeconomics
# ...     ...     ...      ...     ...     ...                             ...
# 69063  2010  Summer  2010-su    STAT     400    Statistics and Probability I
# 69064  2010  Summer  2010-su    STAT     410   Statistics and Probability II
# 69065  2010  Summer  2010-su    STAT     440     Statistical Data Management
# 69066  2010  Summer  2010-su     TAM     212           Introductory Dynamics
# 69068  2010  Summer  2010-su     TAM     335    Introductory Fluid Mechanics
#
#       Sched Type  A+   A  A-  ...   C  C-  D+  D  D-  F  W
# 5            LEC   0   5   4  ...   3   1   0  1   0  0  0  \
# 106          LEC  10  19  13  ...   9   5   1  2   1  0  0
# 113          LEC  13  13   8  ...   7   4   2  2   1  0  0
# 115          LEC  20  16   8  ...   0   1   0  0   0  0  0
# 116          LEC  12  20  10  ...  10   4   4  4   1  1  0
# ...          ...  ..  ..  ..  ...  ..  ..  .. ..  .. .. ..
# 69063        LEC   4  15   7  ...   2   2   0  1   0  3  1
# 69064        LEC   5  10   2  ...   1   3   0  0   0  2  1
# 69065        LEC   4  12   8  ...   0   0   0  0   0  0  0
# 69066        LEC   0   1   3  ...   1   1   0  2   0  1  0
# 69068        LEC   5   8   9  ...   4   0   0  1   0  2  0
#
#        Primary Instructor  Students  Average GPA
# 5      Leonelli, Laurie B        27     3.098889
# 106         Damon, Lisa A        89     3.101573
# 113     Gundersen, Lisa C        71     3.122394
# 115     Gundersen, Lisa C        58     3.712931
# 116        Endres, Renata        98     3.003571
# ...                   ...       ...          ...
# 69063      Monrad, Ditlev        47     3.142553
# 69064  Stepanov, Alexei G        31     3.183226
# 69065        Unger, David        28     3.774643
# 69066   Morgan, William T        28     2.595714
# 69068    Keane, Richard D        39     3.205641
#
# [8357 rows x 24 columns]

# %%
popular_course = df[(df.Subject == 'CS') & (df.Number == 225)]

# %%
# Add a row number within each group of 'Primary Instructor' and 'YearTerm' for uniqueness
popular_course['RowNumber'] = popular_course.groupby(['Primary Instructor', 'YearTerm']).cumcount() + 1

# Create a detailed section identifier
popular_course['DetailedSection'] = (
    popular_course['Primary Instructor'] + ' - ' +
    popular_course['YearTerm'] + ' - ' +
    popular_course['Number'].astype(str) + ' - ' +
    popular_course['RowNumber'].astype(str)
)

chart = alt.Chart(popular_course).mark_bar().encode(
    x=alt.X('DetailedSection:N', axis=alt.Axis(title='Section')),
    y=alt.Y('Average GPA:Q', axis=alt.Axis(title='Average GPA')),
    color=alt.Color('Primary Instructor:N', legend=alt.Legend(title="Instructor")),
    tooltip=['DetailedSection', 'Average GPA']
).properties(
    width=800,
    height=400,
    title='Average GPA for Each Section of CS 225 Taught by Instructor'
)

chart
# Out:
# C:\Users\echen\AppData\Local\Temp\ipykernel_32132\2512238875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popular_course['RowNumber'] = popular_course.groupby(['Primary Instructor', 'YearTerm']).cumcount() + 1
# C:\Users\echen\AppData\Local\Temp\ipykernel_32132\2512238875.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popular_course['DetailedSection'] = (
# alt.Chart(...)

# %% [markdown]
# ## Creating Final Version w/ Interactivity to Select Course

# %%
# To support interactivity, make CS courses
CS_Courses = df[(df.Subject == 'CS') & (df.Number.isin([105, 173, 225, 374, 446]))] 

# Create dropdown and selection for course number
dropdown = alt.binding_select(options=[105, 173, 225, 374, 446], 
                              labels=["CS 105", "CS 173", "CS 225", "CS 374", "CS 446"], 
                              name="Course: ",) 

course_selection = alt.selection_point(fields=['Number'], 
                                       bind=dropdown, 
                                       name="Course: ", 
                                       value=225) 

# Add a row number within each group of 'Primary Instructor' and 'YearTerm' for uniqueness
CS_Courses['RowNumber'] = CS_Courses.groupby(['Primary Instructor', 'YearTerm']).cumcount() + 1

# Create a detailed section identifier
CS_Courses['DetailedSection'] = (
    CS_Courses['Primary Instructor'] + ' - ' +
    CS_Courses['YearTerm'] + ' - ' +
    CS_Courses['Number'].astype(str) + ' - ' +
    CS_Courses['RowNumber'].astype(str)
)

chart = alt.Chart(CS_Courses).mark_bar().encode(
    x=alt.X('DetailedSection:N', axis=alt.Axis(title='Section')),
    y=alt.Y('Average GPA:Q', axis=alt.Axis(title='Average GPA')),
    color=alt.Color('Primary Instructor:N', legend=alt.Legend(title="Instructor")),
    tooltip=['DetailedSection', 'Average GPA']
).properties(
    width=800,
    height=400,
    title=f'Average GPA for Each Class Section Taught by Instructor'
).add_params(
    course_selection
).transform_filter(
    course_selection
).configure_title(
    fontSize=16
)

chart
chart.save('final-proj-viz1.json', format='json')
# Out:
# C:\Users\echen\AppData\Local\Temp\ipykernel_32132\827556400.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS_Courses['RowNumber'] = CS_Courses.groupby(['Primary Instructor', 'YearTerm']).cumcount() + 1
# C:\Users\echen\AppData\Local\Temp\ipykernel_32132\827556400.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS_Courses['DetailedSection'] = (

# %% [markdown]
# For the writeup, I was going to introduce something along the lines of "Does the Professor teaching really matter?", in this visualization we're presenting a case study that showcases a class that many students have taken that has had many different instructors. You can easily examine the chart by interacting with it to see the disparities.

# %%
df.Subject.nunique()
# Out:
# 95

# %%
df
# Out:
#        Year    Term YearTerm Subject  Number                    Course Title
# 5      2023  Spring  2023-sp     ABE     141      ABE Principles: Biological  \
# 106    2023  Spring  2023-sp     ACE     210         Environmental Economics
# 113    2023  Spring  2023-sp     ACE     262  App Stat Mthds & Data AnlytcsI
# 115    2023  Spring  2023-sp     ACE     270              Consumer Economics
# 116    2023  Spring  2023-sp     ACE     300  Interm. Applied Microeconomics
# ...     ...     ...      ...     ...     ...                             ...
# 69063  2010  Summer  2010-su    STAT     400    Statistics and Probability I
# 69064  2010  Summer  2010-su    STAT     410   Statistics and Probability II
# 69065  2010  Summer  2010-su    STAT     440     Statistical Data Management
# 69066  2010  Summer  2010-su     TAM     212           Introductory Dynamics
# 69068  2010  Summer  2010-su     TAM     335    Introductory Fluid Mechanics
#
#       Sched Type  A+   A  A-  ...   C  C-  D+  D  D-  F  W
# 5            LEC   0   5   4  ...   3   1   0  1   0  0  0  \
# 106          LEC  10  19  13  ...   9   5   1  2   1  0  0
# 113          LEC  13  13   8  ...   7   4   2  2   1  0  0
# 115          LEC  20  16   8  ...   0   1   0  0   0  0  0
# 116          LEC  12  20  10  ...  10   4   4  4   1  1  0
# ...          ...  ..  ..  ..  ...  ..  ..  .. ..  .. .. ..
# 69063        LEC   4  15   7  ...   2   2   0  1   0  3  1
# 69064        LEC   5  10   2  ...   1   3   0  0   0  2  1
# 69065        LEC   4  12   8  ...   0   0   0  0   0  0  0
# 69066        LEC   0   1   3  ...   1   1   0  2   0  1  0
# 69068        LEC   5   8   9  ...   4   0   0  1   0  2  0
#
#        Primary Instructor  Students  Average GPA
# 5      Leonelli, Laurie B        27     3.098889
# 106         Damon, Lisa A        89     3.101573
# 113     Gundersen, Lisa C        71     3.122394
# 115     Gundersen, Lisa C        58     3.712931
# 116        Endres, Renata        98     3.003571
# ...                   ...       ...          ...
# 69063      Monrad, Ditlev        47     3.142553
# 69064  Stepanov, Alexei G        31     3.183226
# 69065        Unger, David        28     3.774643
# 69066   Morgan, William T        28     2.595714
# 69068    Keane, Richard D        39     3.205641
#
# [8357 rows x 24 columns]

# %% [markdown]
# # Contextual Visualizations
# Using the Graybook Prof. Appointment Data from CS

# %%
graybook = pd.read_csv('https://raw.githubusercontent.com/zuyouchen/107_datasets/main/graybook/graybook-clean-sp23.csv')
graybook
# Out:
#                Employee Name                    Job Title Tenure Empl Class
# 0      Gerstenecker, David G          DIR OF INFO TECHNOL    NaN         BA  \
# 1        Henry, Joshua Keith       ASSOC DIR INFO TECHNOL    NaN         BA
# 2            Meyer, Donald L             SR NETWORK ANLYS    NaN         BA
# 3            Schwartz, Sarah                   COMM COORD    NaN         BA
# 4      Winter-Nelson, Alex E                    DIR, ADMI    NaN        NaN
# ...                      ...                          ...    ...        ...
# 6014       Chambers, Sonya L  EXEC DIR STRATG INITIATIVES    NaN         BA
# 6015         Garrick, Sean C  VC FOR DVSTY, EQUITY & INCL    NaN        NaN
# 6016  Guerra Perez, Gioconda      EXEC ASSOC VC FOR DVSTY    NaN         BA
# 6017    VanDuyne, Adam Jareb          EXEC DIR FIN & ADMN    NaN         BA
# 6018        Wantland, Ross A      DIR OF CURR DEVL & EDUC    NaN         BA
#
#       Present FTE  Proposed FTE  Present Salary  Proposed Salary College Code
# 0             1.0           1.0       106476.00        109670.28           KL  \
# 1             1.0           1.0        80871.33         83701.83           KL
# 2             1.0           1.0        89558.22         92692.76           KL
# 3             1.0           1.0        50000.00         51750.00           KL
# 4             1.0           1.0       186666.00        193532.64           KL
# ...           ...           ...             ...              ...          ...
# 6014          1.0           1.0       163200.00        169500.00           NV
# 6015          1.0           1.0       338248.98        351778.94           NV
# 6016          1.0           1.0       178500.00        187250.00           NV
# 6017          1.0           1.0       141000.00        147200.00           NV
# 6018          1.0           1.0        94860.00         98860.00           NV
#
#                        College Name  Department Code
# 0      Agr, Consumer & Env Sciences              348  \
# 1      Agr, Consumer & Env Sciences              348
# 2      Agr, Consumer & Env Sciences              348
# 3      Agr, Consumer & Env Sciences              521
# 4      Agr, Consumer & Env Sciences              521
# ...                             ...              ...
# 6014  Vice Chancellor for Diversity              594
# 6015  Vice Chancellor for Diversity              594
# 6016  Vice Chancellor for Diversity              594
# 6017  Vice Chancellor for Diversity              594
# 6018  Vice Chancellor for Diversity              594
#
#                     Department Name
# 0          ACES Technology Services  \
# 1          ACES Technology Services
# 2          ACES Technology Services
# 3             ADM Institute for PHL
# 4             ADM Institute for PHL
# ...                             ...
# 6014  Vice Chancellor for Diversity
# 6015  Vice Chancellor for Diversity
# 6016  Vice Chancellor for Diversity
# 6017  Vice Chancellor for Diversity
# 6018  Vice Chancellor for Diversity
#
#                                              Job Titles Employee Classes
# 0                               ['DIR OF INFO TECHNOL']           ['BA']
# 1                            ['ASSOC DIR INFO TECHNOL']           ['BA']
# 2                                  ['SR NETWORK ANLYS']           ['BA']
# 3                                        ['COMM COORD']           ['BA']
# 4     ['DIR, ADMI', 'ASSOC DEAN FOR INATL PRGMS', 'P...     ['AA', 'BA']
# ...                                                 ...              ...
# 6014                    ['EXEC DIR STRATG INITIATIVES']           ['BA']
# 6015                    ['VC FOR DVSTY, EQUITY & INCL']           ['BA']
# 6016                        ['EXEC ASSOC VC FOR DVSTY']           ['BA']
# 6017                            ['EXEC DIR FIN & ADMN']           ['BA']
# 6018                        ['DIR OF CURR DEVL & EDUC']           ['BA']
#
# [6019 rows x 14 columns]

# %%
# CS is department code 434
graybook_CS = graybook[graybook['Department Code'] == 434]
graybook_CS
# Out:
#                      Employee Name                     Job Title Tenure
# 2573             Abdelzaher, Tarek                          PROF    NaN  \
# 2574                Adve, Sarita V                          PROF    NaN
# 2575         Adve, Vikram Sadanand                          PROF    NaN
# 2576  Alawini, Abdussalam Alhadi M                 TCH ASST PROF      M
# 2577            Amato, Nancy Marie                          HEAD    NaN
# ...                            ...                           ...    ...
# 2725              Zhai, Chengxiang                          PROF    NaN
# 2726               Zhang, Lingming                    ASSOC PROF      A
# 2727                     Zhao, Han                     ASST PROF    NaN
# 2728                 Zike, Heather  UGRAD PRGM COORD & ACAD ADVR    NaN
# 2729                 Zilles, Craig                          PROF      A
#
#      Empl Class  Present FTE  Proposed FTE  Present Salary  Proposed Salary
# 2573        NaN          1.0           1.0        208154.0         217521.0  \
# 2574        NaN          1.0           1.0        218504.0         230000.0
# 2575        NaN          1.0           1.0        218462.0         230000.0
# 2576         AA          1.0           1.0        105575.0         110326.0
# 2577        NaN          1.0           1.0        272500.0         289238.0
# ...         ...          ...           ...             ...              ...
# 2725        NaN          1.0           1.0        187107.0         195527.0
# 2726         AA          1.0           1.0        140600.0         146927.0
# 2727        NaN          1.0           1.0        125000.0         130625.0
# 2728         BA          1.0           1.0         62968.4          65487.4
# 2729         AA          1.0           1.0        167000.0         174515.0
#
#      College Code          College Name  Department Code   Department Name
# 2573           KP  Grainger Engineering              434  Computer Science  \
# 2574           KP  Grainger Engineering              434  Computer Science
# 2575           KP  Grainger Engineering              434  Computer Science
# 2576           KP  Grainger Engineering              434  Computer Science
# 2577           KP  Grainger Engineering              434  Computer Science
# ...           ...                   ...              ...               ...
# 2725           KP  Grainger Engineering              434  Computer Science
# 2726           KP  Grainger Engineering              434  Computer Science
# 2727           KP  Grainger Engineering              434  Computer Science
# 2728           KP  Grainger Engineering              434  Computer Science
# 2729           KP  Grainger Engineering              434  Computer Science
#
#                                              Job Titles Employee Classes
# 2573                 ['PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']
# 2574                 ['PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']
# 2575   ['PROF, NCSA', 'PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']
# 2576                                  ['TCH ASST PROF']           ['AA']
# 2577  ['HEAD', 'PROF', 'PROF, HCESC', 'PROF, NCSA', ...     ['AA', 'BA']
# ...                                                 ...              ...
# 2725   ['PROF, IGB', 'WILLETT FACULTY SCHOLAR', 'PROF']           ['AA']
# 2726                                     ['ASSOC PROF']           ['AA']
# 2727                                      ['ASST PROF']           ['AA']
# 2728                   ['UGRAD PRGM COORD & ACAD ADVR']           ['BA']
# 2729                                           ['PROF']           ['AA']
#
# [157 rows x 14 columns]

# %%
# Narrow down to only include instructors who have 'PROF' in their Job Title
def profInJobTitle(jobTitle):
    if 'PROF' in jobTitle:
        return True
    return False

# Apply the function to the Job Titles column
graybook_CS.loc[:, 'Teaching'] = graybook_CS['Job Title'].apply(profInJobTitle)
# Subset the dataframe to only include instructors who have 'PROF' in their Job Title
graybook_CS_prof = graybook_CS[graybook_CS['Teaching'] == True]
graybook_CS_prof
# Out:
# C:\Users\echen\AppData\Local\Temp\ipykernel_32132\1781993938.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   graybook_CS.loc[:, 'Teaching'] = graybook_CS['Job Title'].apply(profInJobTitle)
#                       Employee Name      Job Title Tenure Empl Class
# 2573              Abdelzaher, Tarek           PROF    NaN        NaN  \
# 2574                 Adve, Sarita V           PROF    NaN        NaN
# 2575          Adve, Vikram Sadanand           PROF    NaN        NaN
# 2576   Alawini, Abdussalam Alhadi M  TCH ASST PROF      M         AA
# 2578  Angrave, Lawrence Christopher       TCH PROF      M         AA
# ...                             ...            ...    ...        ...
# 2723              Yuile, Adam Bates     ASSOC PROF    NaN        NaN
# 2725               Zhai, Chengxiang           PROF    NaN        NaN
# 2726                Zhang, Lingming     ASSOC PROF      A         AA
# 2727                      Zhao, Han      ASST PROF    NaN        NaN
# 2729                  Zilles, Craig           PROF      A         AA
#
#       Present FTE  Proposed FTE  Present Salary  Proposed Salary College Code
# 2573          1.0           1.0        208154.0         217521.0           KP  \
# 2574          1.0           1.0        218504.0         230000.0           KP
# 2575          1.0           1.0        218462.0         230000.0           KP
# 2576          1.0           1.0        105575.0         110326.0           KP
# 2578          1.0           1.0        147088.0         153707.0           KP
# ...           ...           ...             ...              ...          ...
# 2723          1.0           1.0        129540.0         143369.0           KP
# 2725          1.0           1.0        187107.0         195527.0           KP
# 2726          1.0           1.0        140600.0         146927.0           KP
# 2727          1.0           1.0        125000.0         130625.0           KP
# 2729          1.0           1.0        167000.0         174515.0           KP
#
#               College Name  Department Code   Department Name
# 2573  Grainger Engineering              434  Computer Science  \
# 2574  Grainger Engineering              434  Computer Science
# 2575  Grainger Engineering              434  Computer Science
# 2576  Grainger Engineering              434  Computer Science
# 2578  Grainger Engineering              434  Computer Science
# ...                    ...              ...               ...
# 2723  Grainger Engineering              434  Computer Science
# 2725  Grainger Engineering              434  Computer Science
# 2726  Grainger Engineering              434  Computer Science
# 2727  Grainger Engineering              434  Computer Science
# 2729  Grainger Engineering              434  Computer Science
#
#                                             Job Titles Employee Classes
# 2573                ['PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']  \
# 2574                ['PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']
# 2575  ['PROF, NCSA', 'PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']
# 2576                                 ['TCH ASST PROF']           ['AA']
# 2578                                      ['TCH PROF']           ['AA']
# ...                                                ...              ...
# 2723                 ['ASSOC PROF, ITI', 'ASSOC PROF']           ['AA']
# 2725  ['PROF, IGB', 'WILLETT FACULTY SCHOLAR', 'PROF']           ['AA']
# 2726                                    ['ASSOC PROF']           ['AA']
# 2727                                     ['ASST PROF']           ['AA']
# 2729                                          ['PROF']           ['AA']
#
#       Teaching
# 2573      True
# 2574      True
# 2575      True
# 2576      True
# 2578      True
# ...        ...
# 2723      True
# 2725      True
# 2726      True
# 2727      True
# 2729      True
#
# [126 rows x 15 columns]

# %%
# Reduce the number of columns to only be when the professor has a non-unique 'Job Title' 
graybook_CS_prof_nonunique = graybook_CS_prof[graybook_CS_prof['Job Title'].duplicated(keep=False)]

# Replace job title acronyms to avoid jargon
title_mapping = {"ASST": "Assistant", 
                 "PROF": "Professor", 
                 "RES": "Research", 
                 "TCH": "Teaching", 
                 "ASSOC": "Associate"}

graybook_CS_prof_nonunique.loc[:,'Job Title'] = graybook_CS_prof_nonunique['Job Title'].replace(title_mapping, regex=True)

# Chart that shows a count of the professors in job titles, ordered by count

chart2 = alt.Chart(graybook_CS_prof_nonunique).mark_bar().encode(
    x=alt.X('Job Title:N', axis=alt.Axis(title='Job Title', labelAngle=20, labelOffset=-15, titlePadding=10), sort='-y'),
    y=alt.Y('count():Q', axis=alt.Axis(title='Number of Professors', titlePadding=10)),
    color=alt.Color('Job Title:N', legend=alt.Legend(title="Job Title")),
    tooltip=[alt.Tooltip('Job Title:N', title='Job Title'), alt.Tooltip('count():Q', title='Number of Professors')]
).properties(
    width=800,
    height=400,
    title='Job Titles of Spring 2023 CS Professors',
).configure_title(
    fontSize=16  # Adjust fontSize as needed
)

chart2.save('final-proj-3.1-contextual-job-titles.json', format='json')

# %%
graybook_CS_prof['Tenure'].unique()
# Out:
# array([nan, 'M', 'A', 'P'], dtype=object)

# %%
# According to https://www.trustees.uillinois.edu/trustees/resources/historical-files/GrayBook2022.pdf,
''' 
Tenure Status Meanings
M Multi-Year Contract Agreement
A Indefinite Tenure
P Probationary Term
'''
# Replace NaN values with "unknown"
graybook_CS_prof.loc[:, 'Tenure'] = graybook_CS_prof['Tenure'].fillna('Unknown')
# Replace M, A, P with their full meanings
tenure_mapping = {"M": "Multi-Year Contract Agreement", 
                 "A": "Indefinite Tenure", 
                 "P": "Probationary Term"}
graybook_CS_prof.loc[:,'Tenure'] = graybook_CS_prof['Tenure'].replace(tenure_mapping, regex=True)
graybook_CS_prof
# Out:
#                       Employee Name      Job Title
# 2573              Abdelzaher, Tarek           PROF  \
# 2574                 Adve, Sarita V           PROF
# 2575          Adve, Vikram Sadanand           PROF
# 2576   Alawini, Abdussalam Alhadi M  TCH ASST PROF
# 2578  Angrave, Lawrence Christopher       TCH PROF
# ...                             ...            ...
# 2723              Yuile, Adam Bates     ASSOC PROF
# 2725               Zhai, Chengxiang           PROF
# 2726                Zhang, Lingming     ASSOC PROF
# 2727                      Zhao, Han      ASST PROF
# 2729                  Zilles, Craig           PROF
#
#                              Tenure Empl Class  Present FTE  Proposed FTE
# 2573                        Unknown        NaN          1.0           1.0  \
# 2574                        Unknown        NaN          1.0           1.0
# 2575                        Unknown        NaN          1.0           1.0
# 2576  Multi-Year Contract Agreement         AA          1.0           1.0
# 2578  Multi-Year Contract Agreement         AA          1.0           1.0
# ...                             ...        ...          ...           ...
# 2723                        Unknown        NaN          1.0           1.0
# 2725                        Unknown        NaN          1.0           1.0
# 2726              Indefinite Tenure         AA          1.0           1.0
# 2727                        Unknown        NaN          1.0           1.0
# 2729              Indefinite Tenure         AA          1.0           1.0
#
#       Present Salary  Proposed Salary College Code          College Name
# 2573        208154.0         217521.0           KP  Grainger Engineering  \
# 2574        218504.0         230000.0           KP  Grainger Engineering
# 2575        218462.0         230000.0           KP  Grainger Engineering
# 2576        105575.0         110326.0           KP  Grainger Engineering
# 2578        147088.0         153707.0           KP  Grainger Engineering
# ...              ...              ...          ...                   ...
# 2723        129540.0         143369.0           KP  Grainger Engineering
# 2725        187107.0         195527.0           KP  Grainger Engineering
# 2726        140600.0         146927.0           KP  Grainger Engineering
# 2727        125000.0         130625.0           KP  Grainger Engineering
# 2729        167000.0         174515.0           KP  Grainger Engineering
#
#       Department Code   Department Name
# 2573              434  Computer Science  \
# 2574              434  Computer Science
# 2575              434  Computer Science
# 2576              434  Computer Science
# 2578              434  Computer Science
# ...               ...               ...
# 2723              434  Computer Science
# 2725              434  Computer Science
# 2726              434  Computer Science
# 2727              434  Computer Science
# 2729              434  Computer Science
#
#                                             Job Titles Employee Classes
# 2573                ['PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']  \
# 2574                ['PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']
# 2575  ['PROF, NCSA', 'PROF', 'PROF, ITI', 'PROF, CSL']           ['AA']
# 2576                                 ['TCH ASST PROF']           ['AA']
# 2578                                      ['TCH PROF']           ['AA']
# ...                                                ...              ...
# 2723                 ['ASSOC PROF, ITI', 'ASSOC PROF']           ['AA']
# 2725  ['PROF, IGB', 'WILLETT FACULTY SCHOLAR', 'PROF']           ['AA']
# 2726                                    ['ASSOC PROF']           ['AA']
# 2727                                     ['ASST PROF']           ['AA']
# 2729                                          ['PROF']           ['AA']
#
#       Teaching
# 2573      True
# 2574      True
# 2575      True
# 2576      True
# 2578      True
# ...        ...
# 2723      True
# 2725      True
# 2726      True
# 2727      True
# 2729      True
#
# [126 rows x 15 columns]

# %%
# Now, generating visualization showing distribution of tenure status of CS professors
chart3 = alt.Chart(graybook_CS_prof).mark_bar().encode(
    x=alt.X('Tenure:N', axis=alt.Axis(title='Tenure Status', labelAngle=0, titlePadding=10)),
    y=alt.Y('count():Q', axis=alt.Axis(title='Number of Professors', titlePadding=10)),
    color=alt.Color('Tenure:N', legend=alt.Legend(title="Tenure Status")),
    tooltip=[alt.Tooltip('Tenure:N', title='Tenure Status'), alt.Tooltip('count():Q', title='Number of Professors')]
).properties(
    width=800,
    height=400,
    title='Tenure Status of Spring 2023 CS Professors'
).configure_title(
    fontSize=16
)

chart3.save('final-proj-3.1-contextual-tenure.json', format='json')
